# %%
from sklearn.linear_model import (
    LinearRegression,
    Ridge,
    Lasso,
    Huber,
    TheilSenRegressor,
    RANSACRegressor
)
from sklearn.model_selection import (
    train_test_split,
    cross_val_score,
    KFold
)
from sklearn.metrics import (
    mean_absolute_error as MAE,
    root_mean_squared_error as RMSE,
    mean_squared_error as MSE,
    median_absolute_error as MdAE,
    r2_score as R2
)
from sklearn.pipeline import Pipeline 
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data_for_model.csv", delimiter=';', header=None)
df.columns = ['ID', 'TerritoryName', 'TerritoryGroup', 'CountryRegionCode', 'ShipMethodName', 'TotalUnits', 'Avg_StdCost', 'TotalDue']
df
# Out:
#           ID TerritoryName TerritoryGroup CountryRegionCode  \
# 0      43659     Southeast  North America                US
# 1      43660     Southeast  North America                US
# 2      43661        Canada  North America                CA
# 3      43662        Canada  North America                CA
# 4      43663     Southwest  North America                US
# ...      ...           ...            ...               ...
# 31460  75119     Northwest  North America                US
# 31461  75120        Canada  North America                CA
# 31462  75121        Canada  North America                CA
# 31463  75122        Canada  North America                CA
# 31464  75123        Canada  North America                CA
#
#            ShipMethodName  TotalUnits  Avg_StdCost    TotalDue
# 0       CARGO TRANSPORT 5          26    1120.2741  23153.2339
# 1       CARGO TRANSPORT 5           2     685.7074   1457.3288
# 2       CARGO TRANSPORT 5          38     883.0531  36865.8012
# 3       CARGO TRANSPORT 5          54     619.8741  32474.9324
# 4       CARGO TRANSPORT 5           1     486.7066    472.3108
# ...                   ...         ...          ...         ...
# 31460  XRQ - TRUCK GROUND           3       5.2709     46.7194
# 31461  XRQ - TRUCK GROUND           3      18.9050     93.8808
# 31462  XRQ - TRUCK GROUND           3       9.3475     82.8529
# 31463  XRQ - TRUCK GROUND           2       7.5714     34.2219
# 31464  XRQ - TRUCK GROUND           3      24.8696    209.9169
#
# [31465 rows x 8 columns]

# %%
df['TerritoryName'].unique()
df['TerritoryName'] = df['TerritoryName'].replace({
    'Southeast':0,
    'Canada':1,
    'Southwest':2,
    'Northwest':3,
    'Central':4,
    'Northeast':5,
    'France':6,
    'Australia':7,
    'United Kingdom':8,
    'Germany':9
})

# %%
df = pd.get_dummies(df, columns = ['TerritoryName', 'TerritoryGroup', 'CountryRegionCode', 'ShipMethodName'])

# %%
df
# Out:
#           ID  TotalUnits  Avg_StdCost    TotalDue  TerritoryName_Australia  \
# 0      43659          26    1120.2741  23153.2339                    False
# 1      43660           2     685.7074   1457.3288                    False
# 2      43661          38     883.0531  36865.8012                    False
# 3      43662          54     619.8741  32474.9324                    False
# 4      43663           1     486.7066    472.3108                    False
# ...      ...         ...          ...         ...                      ...
# 31460  75119           3       5.2709     46.7194                    False
# 31461  75120           3      18.9050     93.8808                    False
# 31462  75121           3       9.3475     82.8529                    False
# 31463  75122           2       7.5714     34.2219                    False
# 31464  75123           3      24.8696    209.9169                    False
#
#        TerritoryName_Canada  TerritoryName_Central  TerritoryName_France  \
# 0                     False                  False                 False
# 1                     False                  False                 False
# 2                      True                  False                 False
# 3                      True                  False                 False
# 4                     False                  False                 False
# ...                     ...                    ...                   ...
# 31460                 False                  False                 False
# 31461                  True                  False                 False
# 31462                  True                  False                 False
# 31463                  True                  False                 False
# 31464                  True                  False                 False
#
#        TerritoryName_Germany  TerritoryName_Northeast  ...  \
# 0                      False                    False  ...
# 1                      False                    False  ...
# 2                      False                    False  ...
# 3                      False                    False  ...
# 4                      False                    False  ...
# ...                      ...                      ...  ...
# 31460                  False                    False  ...
# 31461                  False                    False  ...
# 31462                  False                    False  ...
# 31463                  False                    False  ...
# 31464                  False                    False  ...
#
#        TerritoryGroup_North America  TerritoryGroup_Pacific  \
# 0                              True                   False
# 1                              True                   False
# 2                              True                   False
# 3                              True                   False
# 4                              True                   False
# ...                             ...                     ...
# 31460                          True                   False
# 31461                          True                   False
# 31462                          True                   False
# 31463                          True                   False
# 31464                          True                   False
#
#        CountryRegionCode_AU  CountryRegionCode_CA  CountryRegionCode_DE  \
# 0                     False                 False                 False
# 1                     False                 False                 False
# 2                     False                  True                 False
# 3                     False                  True                 False
# 4                     False                 False                 False
# ...                     ...                   ...                   ...
# 31460                 False                 False                 False
# 31461                 False                  True                 False
# 31462                 False                  True                 False
# 31463                 False                  True                 False
# 31464                 False                  True                 False
#
#        CountryRegionCode_FR  CountryRegionCode_GB  CountryRegionCode_US  \
# 0                     False                 False                  True
# 1                     False                 False                  True
# 2                     False                 False                 False
# 3                     False                 False                 False
# 4                     False                 False                  True
# ...                     ...                   ...                   ...
# 31460                 False                 False                  True
# 31461                 False                 False                 False
# 31462                 False                 False                 False
# 31463                 False                 False                 False
# 31464                 False                 False                 False
#
#        ShipMethodName_CARGO TRANSPORT 5  ShipMethodName_XRQ - TRUCK GROUND
# 0                                  True                              False
# 1                                  True                              False
# 2                                  True                              False
# 3                                  True                              False
# 4                                  True                              False
# ...                                 ...                                ...
# 31460                             False                               True
# 31461                             False                               True
# 31462                             False                               True
# 31463                             False                               True
# 31464                             False                               True
#
# [31465 rows x 25 columns]

# %%
X = df.drop(columns=['ID', 'TotalDue'])
y = df['TotalDue']

X
# Out:
#        TotalUnits  Avg_StdCost  TerritoryName_Australia  TerritoryName_Canada  \
# 0              26    1120.2741                    False                 False
# 1               2     685.7074                    False                 False
# 2              38     883.0531                    False                  True
# 3              54     619.8741                    False                  True
# 4               1     486.7066                    False                 False
# ...           ...          ...                      ...                   ...
# 31460           3       5.2709                    False                 False
# 31461           3      18.9050                    False                  True
# 31462           3       9.3475                    False                  True
# 31463           2       7.5714                    False                  True
# 31464           3      24.8696                    False                  True
#
#        TerritoryName_Central  TerritoryName_France  TerritoryName_Germany  \
# 0                      False                 False                  False
# 1                      False                 False                  False
# 2                      False                 False                  False
# 3                      False                 False                  False
# 4                      False                 False                  False
# ...                      ...                   ...                    ...
# 31460                  False                 False                  False
# 31461                  False                 False                  False
# 31462                  False                 False                  False
# 31463                  False                 False                  False
# 31464                  False                 False                  False
#
#        TerritoryName_Northeast  TerritoryName_Northwest  \
# 0                        False                    False
# 1                        False                    False
# 2                        False                    False
# 3                        False                    False
# 4                        False                    False
# ...                        ...                      ...
# 31460                    False                     True
# 31461                    False                    False
# 31462                    False                    False
# 31463                    False                    False
# 31464                    False                    False
#
#        TerritoryName_Southeast  ...  TerritoryGroup_North America  \
# 0                         True  ...                          True
# 1                         True  ...                          True
# 2                        False  ...                          True
# 3                        False  ...                          True
# 4                        False  ...                          True
# ...                        ...  ...                           ...
# 31460                    False  ...                          True
# 31461                    False  ...                          True
# 31462                    False  ...                          True
# 31463                    False  ...                          True
# 31464                    False  ...                          True
#
#        TerritoryGroup_Pacific  CountryRegionCode_AU  CountryRegionCode_CA  \
# 0                       False                 False                 False
# 1                       False                 False                 False
# 2                       False                 False                  True
# 3                       False                 False                  True
# 4                       False                 False                 False
# ...                       ...                   ...                   ...
# 31460                   False                 False                 False
# 31461                   False                 False                  True
# 31462                   False                 False                  True
# 31463                   False                 False                  True
# 31464                   False                 False                  True
#
#        CountryRegionCode_DE  CountryRegionCode_FR  CountryRegionCode_GB  \
# 0                     False                 False                 False
# 1                     False                 False                 False
# 2                     False                 False                 False
# 3                     False                 False                 False
# 4                     False                 False                 False
# ...                     ...                   ...                   ...
# 31460                 False                 False                 False
# 31461                 False                 False                 False
# 31462                 False                 False                 False
# 31463                 False                 False                 False
# 31464                 False                 False                 False
#
#        CountryRegionCode_US  ShipMethodName_CARGO TRANSPORT 5  \
# 0                      True                              True
# 1                      True                              True
# 2                     False                              True
# 3                     False                              True
# 4                      True                              True
# ...                     ...                               ...
# 31460                  True                             False
# 31461                 False                             False
# 31462                 False                             False
# 31463                 False                             False
# 31464                 False                             False
#
#        ShipMethodName_XRQ - TRUCK GROUND
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
# ...                                  ...
# 31460                               True
# 31461                               True
# 31462                               True
# 31463                               True
# 31464                               True
#
# [31465 rows x 23 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.3)

# %%
df['TotalDue'].mean()
# Out:
# 3915.9951093564277

# %%
avg_model = pd.Series([3916] * 9440)

# %%
y_test.shape
# Out:
# (9440,)

# %%
linear = LinearRegression()

linear.fit(X_train, y_train)
y_pred = linear.predict(X_test)
MAE(y_test, y_pred), RMSE(y_test, y_pred)
# Out:
# (1895.8360173231658, 5830.022432119296)

# %%
ridge = LinearRegression()

ridge.fit(X_train, y_train)
y_predr = ridge.predict(X_test)
MAE(y_test, y_predr), RMSE(y_test, y_predr)
# Out:
# (1895.8360173231658, 5830.022432119296)

# %%
MAE(y_test, avg_model), RMSE(y_test, avg_model)
# Out:
# (5143.885148993643, 12788.72222148543)
